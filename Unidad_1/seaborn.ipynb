# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')
tips = sns.load_dataset('tips')

# %%
# Tema por defect
sns.set_theme()

# Visualización
sns.relplot(data=df, x='sepal_length', y='sepal_width', hue='species', style='species', size='petal_length', sizes=(10, 200))

# %%
dots = sns.load_dataset('dots')
sns.relplot(data=dots, kind='line', x='time', y='firing_rate', col='align', hue='choice', size='coherence', style='choice', facet_kws=dict(sharex=False))

# %%
fmri = sns.load_dataset('fmri')
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', hue='event', style='event', col='region')

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='smoker', col='time')

# %%
sns.displot(data=tips, x='total_bill', col='time', kde=True)

# %%
penguis = sns.load_dataset('penguins')
sns.jointplot(data=penguis, x='bill_length_mm', y='bill_depth_mm', hue='species')
